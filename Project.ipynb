# %%
import Quandl
import datetime
import pandas as pd
import pandas.io.data
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
#from sklearn.ensemble import RandomForestClassifier
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
start = datetime.datetime(2008, 1, 1)
end = datetime.datetime(2014, 8, 15)
#trim_start = '2000-01-01'
#trim_end = '2014-08-15'

# %% [markdown]
# # S&P - 500 ^GSPC Yahoo Finance

# %%
sp =  pd.io.data.get_data_yahoo('^GSPC', start, end)
#sp.head(10)

# %%
sp.columns.values[-1] = 'AdjClose'
sp.columns = sp.columns + '_SP500'
sp['Return_SP500'] = sp['AdjClose_SP500'].pct_change()
sp.columns
#(sp.AdjClose_SP500 == 0).sum()
# Out:
# Index([u'Open_SP500', u'High_SP500', u'Low_SP500', u'Close_SP500', u'Volume_SP500', u'AdjClose_SP500', u'Return_SP500'], dtype='object')

# %%
#sp.Return_SP500.head(10)
#(sp['AdjClose_SP500'] - sp['AdjClose_SP500'][2:])/sp['AdjClose_SP500'][2:]
sp.head()
#sp.Return_SP500.describe()
# Out:
#             Open_SP500  High_SP500  Low_SP500  Close_SP500  Volume_SP500  \
# Date
# 2008-01-02     1467.97     1471.77    1442.07      1447.16    3452650000
# 2008-01-03     1447.55     1456.80    1443.73      1447.16    3429500000
# 2008-01-04     1444.01     1444.01    1411.19      1411.63    4166000000
# 2008-01-07     1414.07     1423.87    1403.45      1416.18    4221260000
# 2008-01-08     1415.71     1430.28    1388.30      1390.19    4705390000
#
#             AdjClose_SP500  Return_SP500
# Date
# 2008-01-02         1447.16           NaN
# 2008-01-03         1447.16      0.000000
# 2008-01-04         1411.63     -0.024552
# 2008-01-07         1416.18      0.003223
# 2008-01-08         1390.19     -0.018352

# %%
#ogtry = sp['Return_SP500'].copy()
#rint logtry.head()
#ogtry = np.log(logtry[1:])
#rint logtry.head()
#plt.hist(logtry)
#ogtry.describe()
#p.log()
#(1416.25-1420.33)/1420.33

# %%
sp['AdjClose_SP500'].plot()
plt.legend(('Dividend Adjusted Close Price S&P-500',))

# %%
sp['Return_SP500'].plot()
plt.legend(('Returns S&P-500',))

# %%
pd.isnull(sp).any().sum()
# Out:
# 1

# %%
sp.shape
# Out:
# (1668, 7)

# %% [markdown]
# # Nasdaq Composite ^IXIC Yahoo Finance

# %%
nasdaq =  pd.io.data.get_data_yahoo('^IXIC', start, end)
#nasdaq.head()

# %%
nasdaq.columns.values[-1] = 'AdjClose'
nasdaq.columns = nasdaq.columns + '_Nasdaq'
nasdaq['Return_Nasdaq'] = nasdaq['AdjClose_Nasdaq'].pct_change()
nasdaq.columns
# Out:
# Index([u'Open_Nasdaq', u'High_Nasdaq', u'Low_Nasdaq', u'Close_Nasdaq', u'Volume_Nasdaq', u'AdjClose_Nasdaq', u'Return_Nasdaq'], dtype='object')

# %%
nasdaq['AdjClose_Nasdaq'].plot()
plt.legend(('Dividend Adjusted Close Price Nasdaq',))

# %%
nasdaq['Return_Nasdaq'].plot()
plt.legend(('Returns Nasdaq',))

# %%
pd.isnull(nasdaq).any().sum()
# Out:
# 1

# %%
nasdaq.shape
# Out:
# (1668, 7)

# %% [markdown]
# # Dow Jones Industrial Average (YFinance - Quandl)

# %%
djia =  Quandl.get("YAHOO/INDEX_DJI", trim_start='2008-01-01', trim_end='2014-08-15', authtoken="mCDHcSdN9mQ_Hubid1Uq")
#djia.head()

# %%
djia.columns.values[-1] = 'AdjClose'
djia.columns = djia.columns + '_Djia'
djia['Return_Djia'] = djia['AdjClose_Djia'].pct_change()
djia.columns
# Out:
# Index([u'Open_Djia', u'High_Djia', u'Low_Djia', u'Close_Djia', u'Volume_Djia', u'AdjClose_Djia', u'Return_Djia'], dtype='object')

# %%
djia['AdjClose_Djia'].plot()
plt.legend(('Dividend Adjusted Close Price Dow Jones',))

# %%
djia['Return_Djia'].plot()
plt.legend(('Returns Dow Jones',))

# %%
pd.isnull(djia).any().sum()
# Out:
# 1

# %%
djia.shape
# Out:
# (1668, 7)

# %% [markdown]
# # 5 Years US Treasury YTM ^FVX Yahoo Finance

# %%
treasury =  pd.io.data.get_data_yahoo('^FVX', start, end)
#treasury.head()

# %%
treasury.columns.values[-1] = 'AdjClose'
treasury.columns = treasury.columns + '_Treasury'
treasury['Return_Treasury'] = treasury['AdjClose_Treasury'].pct_change()
treasury.columns
# Out:
# Index([u'Open_Treasury', u'High_Treasury', u'Low_Treasury', u'Close_Treasury', u'Volume_Treasury', u'AdjClose_Treasury', u'Return_Treasury'], dtype='object')

# %%
treasury['AdjClose_Treasury'].plot()
plt.legend(('5 Year YTM US Treasury',))

# %%
treasury['Return_Treasury'].plot()
plt.legend(('Returns 5 Year US Treasury',))

# %%
pd.isnull(treasury).any().sum()
# Out:
# 1

# %%
treasury.shape
# Out:
# (1667, 7)

# %% [markdown]
# # Hong Kong Hang Seng ^HSI Yahoo Finance

# %%
hkong =  pd.io.data.get_data_yahoo('^HSI', start, end)
#hkong.head()

# %%
hkong.columns.values[-1] = 'AdjClose'
hkong.columns = hkong.columns + '_HKong'
hkong['Return_HKong'] = hkong['AdjClose_HKong'].pct_change()
hkong.columns
# Out:
# Index([u'Open_HKong', u'High_HKong', u'Low_HKong', u'Close_HKong', u'Volume_HKong', u'AdjClose_HKong', u'Return_HKong'], dtype='object')

# %%
hkong['AdjClose_HKong'].plot()
plt.legend(('Closing Adjusted Hong Kong',))

# %%
hkong['Return_HKong'].plot()
plt.legend(('Daily Returns Hong Kong',))

# %%
pd.isnull(hkong).any().sum()
# Out:
# 1

# %%
hkong.shape
# Out:
# (1667, 7)

# %% [markdown]
# # Frankfurt DAX ^GDAXI Yahoo Finance

# %%
frankfurt =  pd.io.data.get_data_yahoo('^GDAXI', start, end)
frankfurt.tail()
# Out:
#                Open     High      Low    Close     Volume  Adj Close
# Date
# 2014-08-11  9106.67  9199.00  9089.31  9180.74   81228900    9180.74
# 2014-08-12  9166.92  9171.94  9050.00  9069.47   74774600    9069.47
# 2014-08-13  9133.84  9213.61  9118.15  9198.88   82251600    9198.88
# 2014-08-14  9161.81  9265.92  9149.41  9225.10   80394300    9225.10
# 2014-08-15  9239.00  9324.57  9067.58  9092.60  110261800    9092.60

# %%
frankfurt.columns.values[-1] = 'AdjClose'
frankfurt.columns = frankfurt.columns + '_Frankfurt'
frankfurt['Return_Frankfurt'] = frankfurt['AdjClose_Frankfurt'].pct_change()
frankfurt.columns
# Out:
# Index([u'Open_Frankfurt', u'High_Frankfurt', u'Low_Frankfurt', u'Close_Frankfurt', u'Volume_Frankfurt', u'AdjClose_Frankfurt', u'Return_Frankfurt'], dtype='object')

# %%
frankfurt['AdjClose_Frankfurt'].plot()
plt.legend(('Closing Adjusted Frankfurt',))

# %%
frankfurt['Return_Frankfurt'].plot()
plt.legend(('Return Frankfurt',))

# %%
pd.isnull(frankfurt).any().sum()
# Out:
# 1

# %%
frankfurt.shape
# Out:
# (1697, 7)

# %% [markdown]
# # Paris CAC 40 ^FCHI Yahoo Finance

# %%
paris =  pd.io.data.get_data_yahoo('^FCHI', start, end)
#paris.tail()

# %%
paris.columns.values[-1] = 'AdjClose'
paris.columns = paris.columns + '_Paris'
paris['Return_Paris'] = paris['AdjClose_Paris'].pct_change()
paris.columns
# Out:
# Index([u'Open_Paris', u'High_Paris', u'Low_Paris', u'Close_Paris', u'Volume_Paris', u'AdjClose_Paris', u'Return_Paris'], dtype='object')

# %%
paris['AdjClose_Paris'].plot()
plt.legend(('Closing Adjusted Paris',))

# %%
paris['Return_Paris'].plot()
plt.legend(('Return Paris Stock Market',))

# %%
pd.isnull(paris).any().sum()
# Out:
# 1

# %%
paris.shape
# Out:
# (1697, 7)

# %% [markdown]
# # Tokyo Nikkei-225 ^N225 Yahoo Finance

# %%
nikkei =  pd.io.data.get_data_yahoo('^N225', start, end)
#nikkei.tail()

# %%
nikkei.columns.values[-1] = 'AdjClose'
nikkei.columns = nikkei.columns + '_Nikkei'
nikkei['Return_Nikkei'] = nikkei['AdjClose_Nikkei'].pct_change()
nikkei.columns
# Out:
# Index([u'Open_Nikkei', u'High_Nikkei', u'Low_Nikkei', u'Close_Nikkei', u'Volume_Nikkei', u'AdjClose_Nikkei', u'Return_Nikkei'], dtype='object')

# %%
nikkei['AdjClose_Nikkei'].plot()
plt.legend(('Closing Adjusted Nikkei',))

# %%
nikkei['Return_Nikkei'].plot()
plt.legend(('Daily Returns Nikkei Index Japan',))

# %%
pd.isnull(nikkei).any().sum()
# Out:
# 1

# %%
nikkei.shape
# Out:
# (1631, 7)

# %% [markdown]
# # London FTSE-100 ^FTSE Yahoo Finance

# %%
london = pd.io.data.get_data_yahoo('^FTSE', start, end)
#london.tail()

# %%
london.columns.values[-1] = 'AdjClose'
london.columns = london.columns + '_London'
london['Return_London'] = london['AdjClose_London'].pct_change()
london.columns
# Out:
# Index([u'Open_London', u'High_London', u'Low_London', u'Close_London', u'Volume_London', u'AdjClose_London', u'Return_London'], dtype='object')

# %%
london['AdjClose_London'].plot()
plt.legend(('Closing Adjusted London',))

# %%
london['Return_London'].plot()
plt.legend(('Daily Return London',))

# %%
pd.isnull(london).any().sum()
# Out:
# 1

# %%
london.shape
# Out:
# (1725, 7)

# %% [markdown]
# # Australia ASX-200 ^AXJO Yahoo Finance

# %%
australia = pd.io.data.get_data_yahoo('^AXJO', start, end)

# %%
australia.columns.values[-1] = 'AdjClose'
australia.columns = australia.columns + '_Australia'
australia['Return_Australia'] = australia['AdjClose_Australia'].pct_change()
australia.columns
australia.head()
# Out:
#             Open_Australia  High_Australia  Low_Australia  Close_Australia  \
# Date
# 2008-01-02          6336.6          6385.7         6326.7           6353.2
# 2008-01-03          6341.6          6341.6         6251.4           6290.7
# 2008-01-04          6308.3          6343.9         6274.7           6306.8
# 2008-01-07          6276.4          6276.4         6148.1           6161.6
# 2008-01-08          6152.2          6185.3         6115.0           6128.1
#
#             Volume_Australia  AdjClose_Australia  Return_Australia
# Date
# 2008-01-02                 0              6353.2               NaN
# 2008-01-03                 0              6290.7         -0.009838
# 2008-01-04                 0              6306.8          0.002559
# 2008-01-07                 0              6161.6         -0.023023
# 2008-01-08                 0              6128.1         -0.005437

# %%
australia['AdjClose_Australia'].plot()
plt.legend(('Closing Adjusted Australia',))

# %%
australia['Return_Australia'].plot()
plt.legend(('Daily Return Australia',))

# %%
pd.isnull(australia).any().sum()
# Out:
# 1

# %%
australia.shape
# Out:
# (1675, 7)

# %% [markdown]
# # Oil Price US Department for Energy (Quandl)

# %%
oil =  Quandl.get("DOE/RWTC", trim_start='2008-01-01', trim_end='2014-08-15', authtoken="mCDHcSdN9mQ_Hubid1Uq")
#oil.tail()

# %%
oil.columns = oil.columns + '_Oil'
oil['Delta_Oil'] = oil['Value_Oil'].pct_change()
oil.columns
# Out:
# Index([u'Value_Oil', u'Delta_Oil'], dtype='object')

# %%
oil['Value_Oil'].plot()
plt.legend(('Daily Oil Price',))

# %%
oil['Delta_Oil'].plot()
plt.legend(('Daily Delta Oil Price',))

# %%
pd.isnull(oil).any().sum()
# Out:
# 1

# %%
oil.shape
# Out:
# (1670, 2)

# %% [markdown]
# # Natural Gas Price (Open Financial Data Project - Quandl)

# %%
#gas =  Quandl.get("OFDP/FUTURE_NG1", trim_start='2000-01-01', trim_end='2014-08-15', authtoken="mCDHcSdN9mQ_Hubid1Uq")
#gas.tail()

# %%
#gas.columns = gas.columns + '_Gas'
#gas['Delta_Gas'] = gas['Open_Gas'].pct_change()
#gas.columns

# %%
#gas['Open_Gas'].plot()
#plt.legend(('Closing Adjusted Gas Companies Index',))

# %%
#gas['Return_Gas'].plot()
#plt.legend(('Return Gas Companies Index',))

# %%
#pd.isnull(gas).any().sum()

# %%
#gas.shape

# %% [markdown]
# # Gold Price (Bundesbank - Quandl)

# %%
gold = Quandl.get("BUNDESBANK/BBK01_WT5511", trim_start="2008-01-01", trim_end="2014-08-15", authtoken="mCDHcSdN9mQ_Hubid1Uq")
#gold.tail()

# %%
gold.columns = gold.columns + '_Gold'
gold['Delta_Gold'] = gold['Value_Gold'].pct_change()
gold.columns
# Out:
# Index([u'Value_Gold', u'Delta_Gold'], dtype='object')

# %%
gold['Value_Gold'].plot()
plt.legend(('Daily Gold Price (Bundesbank)',))

# %%
gold['Delta_Gold'].plot()
plt.legend(('Daily Delta Gold Price (Bundesbank)',))

# %%
pd.isnull(gold).any().sum()
# Out:
# 1

# %%
gold.shape
# Out:
# (1674, 2)

# %% [markdown]
# # Dollar in Euros Rate Exchange

# %%
euro = Quandl.get("QUANDL/EURUSD", trim_start="2008-01-01", trim_end="2014-08-15", authtoken="mCDHcSdN9mQ_Hubid1Uq")
#euro.tail()

# %%
euro.columns = euro.columns + '_Euro'
euro['Delta_Euro'] = euro['Rate_Euro'].pct_change()
euro.columns
# Out:
# Index([u'Rate_Euro', u'High (est)_Euro', u'Low (est)_Euro', u'Delta_Euro'], dtype='object')

# %%
euro['Rate_Euro'].plot()
plt.legend(('Euro VS USD Exchange',))

# %%
euro['Delta_Euro'].plot()
plt.legend(('Euro VS USD Exchange Daily Delta',))

# %%
pd.isnull(euro).any().sum()
# Out:
# 1

# %%
euro.shape
#sp.shape
#type(sp.iloc[:,(sp.shape[1]-1)])
#type(sp)
#sp[['Return_SP500']]
# Out:
# (1729, 4)

# %% [markdown]
# # Dollar in Japanese Yen Rate Exchange

# %%
yen = Quandl.get("QUANDL/USDJPY", trim_start="2008-01-01", trim_end="2014-08-15", authtoken="mCDHcSdN9mQ_Hubid1Uq")
#euro.tail()

# %%
yen.columns = yen.columns + '_Yen'
yen['Delta_Yen'] = yen['Rate_Yen'].pct_change()
yen.columns
# Out:
# Index([u'Rate_Yen', u'High (est)_Yen', u'Low (est)_Yen', u'Delta_Yen'], dtype='object')

# %%
yen['Rate_Yen'].plot()
plt.legend(('Yen VS USD Exchange',))

# %%
yen['Delta_Yen'].plot()
plt.legend(('Yen VS USD Exchange Daily Delta',))

# %%
pd.isnull(yen).any().sum()
# Out:
# 1

# %%
yen.shape
# Out:
# (1729, 4)

# %% [markdown]
# # Dollar in Australian Dollars Rate Exchange

# %%
aud = Quandl.get("QUANDL/USDAUD", trim_start="2008-01-01", trim_end="2014-08-15", authtoken="mCDHcSdN9mQ_Hubid1Uq")
#aud.tail()

# %%
aud.columns = aud.columns + '_Aud'
aud['Delta_Aud'] = aud['Rate_Aud'].pct_change()
aud.columns
# Out:
# Index([u'Rate_Aud', u'High (est)_Aud', u'Low (est)_Aud', u'Delta_Aud'], dtype='object')

# %%
aud['Rate_Aud'].plot()
plt.legend(('Aud VS USD Exchange',))

# %%
aud['Delta_Aud'].plot()
plt.legend(('Aud VS USD Exchange Daily Delta',))

# %%
pd.isnull(aud).any().sum()
# Out:
# 1

# %%
aud.shape
# Out:
# (1729, 4)

# %% [markdown]
# # Datasets to be merged

# %%
datasets = [sp, nasdaq, treasury, hkong, frankfurt, paris, nikkei, london, australia, oil, gold, euro, yen, aud]
#for dataset in datasets:
#    print dataset.shape, '\n'
#range(1,4)

# %% [markdown]
# # Generating time lags returns

# %%
#for dataset in datasets[:9]:
#    columns = dataset.columns
#    #print columns[-2][9:]
#    for i in range(1,4):
#        name = columns[-2][9:] + "Time" + str(i)
#        #print name#dataset[]
#        dataset[name] = dataset.iloc[:,-2].pct_change(i)
#        print dataset.head()
#    print dataset.columns[0]

# %% [markdown]
# # Merging

# %%
to_be_merged = [nasdaq[['Return_Nasdaq']],
                treasury[['Return_Treasury']],
                hkong[['Return_HKong']],
                frankfurt[['Return_Frankfurt']],
                paris[['Return_Paris']],
                nikkei[['Return_Nikkei']],
                london[['Return_London']],
                australia[['Return_Australia']],
                oil[['Delta_Oil']],
                gold[['Delta_Gold']],
                euro[['Delta_Euro']],
                yen[['Delta_Yen']],
                aud[['Delta_Aud']]]
                
finance = sp[['Return_SP500']].join(to_be_merged, how = 'outer')

# %% [markdown]
# # Cleaning and NaN Imputing

# %%
print 'Size of data frame: ' + str(finance.shape)
print 'Number of NaN after merging: ' + str(finance.shape[0]*finance.shape[1] - finance.count().sum())

######
finance = finance.interpolate(method='time')

print 'Number of NaN after time interpolation: ' + str(finance.shape[0]*finance.shape[1] - finance.count().sum())

finance = finance.fillna(finance.mean())

print 'Number of NaN after mean interpolation: ' + str(finance.shape[0]*finance.shape[1] - finance.count().sum())

#print finance.head()
# Out:
# Size of data frame: (1729, 14)
# Number of NaN after merging: 594
# Number of NaN after time interpolation: 26
# Number of NaN after mean interpolation: 0

# %%
finance.head()
# Out:
#             Return_SP500  Return_Nasdaq  Return_Treasury  Return_HKong  \
# Date
# 2008-01-01      0.000332       0.000501         0.000475      0.000128
# 2008-01-02      0.000332       0.000501         0.000475      0.000128
# 2008-01-03      0.000000      -0.002663        -0.003058     -0.024428
# 2008-01-04     -0.024552      -0.037665        -0.027607      0.023521
# 2008-01-07      0.003223      -0.002072        -0.003155     -0.012362
#
#             Return_Frankfurt  Return_Paris  Return_Nikkei  Return_London  \
# Date
# 2008-01-01          0.000287      0.000067       0.000422       0.000120
# 2008-01-02          0.000287      0.000067       0.000422      -0.006226
# 2008-01-03         -0.005120     -0.000771       0.000422       0.009771
# 2008-01-04         -0.012609     -0.017903       0.000422      -0.020202
# 2008-01-07          0.001086      0.001109      -0.012991      -0.002016
#
#             Return_Australia  Delta_Oil  Delta_Gold  Delta_Euro  Delta_Yen  \
# Date
# ...

# %%
#finance.tail()

# %%
#range(30,51)

# %% [markdown]
# # Temporally Shifting

# %%
######## shifting S&P backwards one day in order to have the return 
######## of today matched with the return on yesterday of the other predictors
shiftBack = -1
finance.Return_SP500 = finance.Return_SP500.shift(shiftBack)

# %%
delays = range(1,30)
maxDelay = max(delays)
columns = finance.columns[1:]
for column in columns:
    for delay in delays:
        newcolumn = column + str(delay)
        #print newcolumn
        finance[newcolumn] = finance[column].shift(delay)

# %%
#finance.head()

# %%
#finance.tail()

# %%
#print finance.tail()
#print finance.head()
finance = finance.iloc[maxDelay:-1,:]
print 'Size of data frame: ' + str(finance.shape)

# %%
#axs = pd.tools.plotting.scatter_matrix(finance, diagonal='kde')

#def wrap(txt, width=8):
#    '''helper function to wrap text for long labels'''
#    import textwrap
#    return '\n'.join(textwrap.wrap(txt, width))

#for ax in axs[:,0]: # the left boundary
#    ax.grid('off', axis='both')
#    ax.set_ylabel(wrap(ax.get_ylabel()), rotation=0, va='center', labelpad=20)
#    ax.set_yticks([])

#for ax in axs[-1,:]: # the lower boundary
#    ax.grid('off', axis='both')
#    ax.set_xlabel(wrap(ax.get_xlabel()), rotation=70)
#    ax.set_xticks([])

#pd.scatter_matrix(finance, diagonal='kde', figsize=(10, 10));

# %%
#corr = finance.corr()
##from matplotlib.artist import setp
##setp(x.get_xticklabels(), rotation=90)
#plt.xticks(rotation=70)
#plt.imshow(corr, cmap='hot', interpolation='none')
#plt.colorbar()
#plt.xticks(range(len(corr)), corr.columns)
#plt.yticks(range(len(corr)), corr.columns);

# %%
#from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier

################
## 1 column --> S&P returns
## last column --> S&P returns turned into categorical Up Down
################

finance['UpDown'] = finance['Return_SP500']
finance.UpDown[finance.UpDown >= 0] = 'Up'

finance.UpDown[finance.UpDown < 0] = 'Down'
##print finance.UpDown.tail(), finance.UpDown.head()
##finance.UpDown = finance.UpDown.shift(1)
##print finance.UpDown.tail(), finance.UpDown.head()
##le = preprocessing.LabelEncoder()
##le.fit(finance.UpDown.values)
##list(le.classes_)
##finance.UpDown = le.transform(finance.UpDown) 
##finance

# %%
#performance = np.zeros(shape=(20,13))
#performance[1,0] = 1
#np.zeros(10)[:-1]
#rep = 100
#accuracy = np.zeros(rep)
#accuracy
finance.shape

# %%
index = int(np.floor(finance.shape[0]*0.8))
train, test = finance[:index], finance[index:]
features = finance.columns[1:-1]

# %%
rep = 10
performance = np.zeros(shape=(rep,finance.shape[1]-2))
                       
accuracy = np.zeros(rep)
#print features
for i in range(rep): 
    forest = RandomForestClassifier(n_estimators=100)
    ##finance.UpDown
    ##y, _ = pd.factorize(train['UpDown'])
    forest = forest.fit(train[features], train['UpDown'])
    forestPredicted = forest.predict(test[features])
    forTable = pd.crosstab(test['UpDown'], forestPredicted, rownames=['actual'], colnames=['preds'])
    ##finance['UpDown'] = pd.Categorical(fina
    ##cnce.target, finance.target_names)
    ##print tb
    #print forestPredicted
    accuracy[i] = float(forTable['Up']['Up'] + forTable['Down']['Down'])/forTable.sum().sum()
    #print 'Accuracy: ' +  str(float(forTable['Up']['Up'] + forTable['Down']['Down'])/forTable.sum().sum())
    #print forTable#

    #importances = forest.feature_importances_
    #indices = np.argsort(importances)[::-1]
    performance[i,:] = forest.feature_importances_

print 'Accuracy: ' + str(accuracy.mean()) + '\n'
#print(performance)
importances = performance.mean(axis=0)
indices = np.argsort(importances)[::-1]
# Print the feature ranking
#print("Feature ranking:")
#for f in range(finance.shape[1]-2):
#    print("%d. %s (%f)" % (f + 1, features[indices[f]], importances[indices[f]]))

# %%
from sklearn import svm
from sklearn import linear_model
#model = linear_model.LogisticRegression(C=1e6)
model = svm.NuSVC()
model.fit(train[features], train['UpDown'])  
modelPred = model.predict(test[features])
modelTable = pd.crosstab(test['UpDown'], modelPred, rownames=['actual'], colnames=['preds'])
print float(modelTable['Up']['Up'] + modelTable['Down']['Down'])/modelTable.sum().sum()
#modelTable

# %%
from sklearn import neighbors
#from sklearn import linear_model
#model = linear_model.LogisticRegression(C=1e6)
model = neighbors.KNeighborsClassifier()
model.fit(train[features], train['UpDown'])  
modelPred = model.predict(test[features])
modelTable = pd.crosstab(test['UpDown'], modelPred, rownames=['actual'], colnames=['preds'])
print float(modelTable['Up']['Up'] + modelTable['Down']['Down'])/modelTable.sum().sum()
#modelTable
